# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException    
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path = './chromedriver.exe')
driver.maximize_window()

# %%
driver.get('https://www.iqair.com/us/world-air-quality')

# %%
def check_element_exist(class_name):
    try:
        #aqi = driver.find_element_by_class_name('aqi-value__value')
        aqi = driver.find_element_by_class_name(class_name)
    except NoSuchElementException:
        return False
    return True

# %%
def is_number(text):
    for i in text:
        if i.isalpha():
            return False
    return True

# %%
driver.get('https://www.iqair.com/us/world-air-quality')
country_links = []
city_names = []
aqi_values = []
PM25 = []
PM10 = []
O3 = []
NO2 = []
SO2 = []
CO = []

board = driver.find_element_by_class_name('aqi-ranking')
countries = board.find_elements_by_tag_name('a')

#bo button SEE DETAIL o cuoi cung
countries = countries[:-1]
#countries = countries[:1]

for country in countries:
    #lay ra duong link dan den cac quoc gia trong top
    country_link = board.find_element_by_link_text(country.text).get_attribute('href')
    country_links.append(country_link)
    
for country_link in country_links:
    print('country: ', country_link)
    while True:        
        driver.get(country_link)
        #lay ra mot so thanh pho cua country
        if not check_element_exist('ranking__table'):
            break
            
        ranking_table = driver.find_element_by_class_name('ranking__table')
        cities = ranking_table.find_elements_by_tag_name('a')
        
        remain_city = False #kiem tra xem con thanh pho nao chua duoc duyet hay khong
        for city in cities:
            if city.text not in city_names:
                remain_city = True
                
                city_names.append(city.text)
                print('city name: ', city.text)
                city_link = city.get_attribute('href')
                driver.get(city_link)
        
                #lay ra chi so AQI
                if not check_element_exist('aqi-value__value'):
                    aqi_values.append('NULL')
                    PM25.append('NULL')
                    PM10.append('NULL')
                    O3.append('NULL')
                    NO2.append('NULL')
                    SO2.append('NULL')
                    CO.append('NULL')
                else:
                    aqi = driver.find_element_by_class_name('aqi-value__value')
                    aqi_values.append(aqi.text)
                    #lay ra danh sach cac button chi so
                    button_board = driver.find_element_by_class_name('pollutant-history-type-buttons')
                    buttons = button_board.find_elements_by_tag_name('button')
                    #bo button AQI
                    buttons = buttons[1:]
                    for button in buttons:
                        print('button name: ', button.text)
                        #click vao tung button
                        button.click()
                        #lay chi so cuoi cung cua bieu do trong button
                        chart = driver.find_element_by_class_name('highcharts-series-group')
                        cols = chart.find_elements_by_tag_name('rect')
                        element_to_hover = cols[-1]
                        ActionChains(driver).move_to_element(element_to_hover).perform()
                        values = driver.find_elements_by_tag_name('tspan')
                        if len(values) == 1:
                            index_value = 0
                        else:
                            index_value = values[-2].text
                            if not is_number(index_value):
                                index_value = 0
                                
                        print(index_value)
                        
                        if button.text == 'PM2.5':
                            PM25.append(index_value)
                        elif button.text =='PM10':
                            PM10.append(index_value)
                        elif button.text == 'O3':
                            O3.append(index_value)
                            print('append')
                        elif button.text == 'NO2':
                            NO2.append(index_value)
                        elif button.text == 'SO2':
                            SO2.append(index_value)
                        elif button.text == 'CO':
                            CO.append(index_value)
                        
                    len_aqi_values = len(aqi_values)
                    if len(PM25) < len_aqi_values:
                        PM25.append('NULL')
                    if len(PM10) < len_aqi_values:
                        PM10.append('NULL')
                    if len(O3) < len_aqi_values:
                        O3.append('NULL')
                    if len(NO2) < len_aqi_values:
                        NO2.append('NULL')
                    if len(SO2) < len_aqi_values:
                        SO2.append('NULL')
                    if len(CO) < len_aqi_values:
                        CO.append('NULL')
                    #if len(aqi_values) != len(O3):
                        #print(str(len(aqi_values)) + ' $$$$$ ' + str(len(O3)))
                        #print('---aqi: ', aqi_values[-1])
                        #print('---o3: ', O3[-1])
                        #print('---before: ', O3[-2])
                        #break
                break
        #neu tat ca cac thanh pho da duoc duyet thi ket thuc
        if remain_city == False:
            break
print('finish')
# Out:
# country:  https://www.iqair.com/us/bangladesh
# city name:  Manikganj, Dhaka
# button name:  PM2.5
# 79.8
# city name:  Dhaka, Dhaka
# button name:  PM2.5
# 68.3
# city name:  Sreepur, Dhaka
# button name:  PM2.5
# 50.5
# city name:  Savar, Dhaka
# button name:  PM2.5
# 44.6
# city name:  Narayanganj, Dhaka
# button name:  PM2.5
# 3
# country:  https://www.iqair.com/us/pakistan
# city name:  Faisalabad, Punjab
# button name:  PM2.5
# 105.9
# city name:  Bahawalpur, Punjab
# button name:  PM2.5
# 74.3
# city name:  Lahore, Punjab
# button name:  PM2.5
# 72.1
# city name:  Sahiwal, Punjab
# button name:  PM2.5
# 50.8
# city name:  Karachi, Sindh
# button name:  PM2.5
# 90
# city name:  Peshawar, Khyber Pakhtunkhwa
# button name:  PM2.5
# 33
# city name:  Rawalpindi, Punjab
# button name:  PM2.5
# 31.9
# city name:  Raiwind, Punjab
# button name:  PM2.5
# 30.7
# city name:  Islamabad, Islamabad
# button name:  PM2.5
# 30
# city name:  Muridke, Punjab
# button name:  PM2.5
# 26.8
# country:  https://www.iqair.com/us/mongolia
# city name:  Darhan, Darhan Uul
# button name:  PM2.5
# 36
# city name:  Ulaanbaatar, Ulaanbaatar
# button name:  PM2.5
# 30.5
# button name:  PM10
# 72
# button name:  O3
# 10.5
# append
# button name:  NO2
# 7
# button name:  SO2
# 7
# button name:  CO
# 2
# city name:  Urt, OEmnoegovi
# button name:  PM2.5
# 18
# button name:  PM10
# 52
# button name:  NO2
# 7
# button name:  SO2
# 5
# city name:  Hongor, Suhbaatar
# button name:  PM2.5
# 12
# button name:  PM10
# 14
# button name:  NO2
# 3
# city name:  Ulaan-Uul, East Gobi Aymag
# button name:  PM2.5
# 12
# button name:  PM10
# 16
# button name:  NO2
# 6
# city name:  Tsetserleg, Arhangay
# button name:  PM2.5
# 6.2
# city name:  Chonogol, Suhbaatar
# button name:  PM2.5
# 5
# button name:  PM10
# 9
# button name:  NO2
# 5
# button name:  CO
# 2
# city name:  Sumber, East Aimak
# button name:  PM2.5
# 1
# button name:  PM10
# 19
# button name:  NO2
# 2
# button name:  SO2
# 7.5
# city name:  Ulan Bator, Ulaanbaatar
# country:  https://www.iqair.com/us/afghanistan
# city name:  Kabul, Kabul
# button name:  PM2.5
# 10.2
# country:  https://www.iqair.com/us/india
# city name:  Muzaffarpur, Bihar
# button name:  PM2.5
# 255
# button name:  O3
# 6
# append
# button name:  NO2
# 2.4
# button name:  SO2
# 8.8
# city name:  Pitampura, Delhi
# button name:  PM2.5
# 200.5
# button name:  PM10
# 277
# button name:  O3
# 11
# append
# button name:  NO2
# 58.8
# button name:  SO2
# 8
# button name:  CO
# 2660
# city name:  Bawana, Delhi
# button name:  PM2.5
# 187.5
# button name:  PM10
# 225.9
# button name:  O3
# 17
# append
# button name:  NO2
# 27.2
# button name:  SO2
# 1.6
# button name:  CO
# 1410
# city name:  Patna, Bihar
# button name:  PM2.5
# 172
# button name:  O3
# 58.8
# append
# button name:  NO2
# 108.4
# button name:  SO2
# 20.6
# button name:  CO
# 2590
# city name:  Alipur, Delhi
# button name:  PM2.5
# 168
# button name:  PM10
# 202
# button name:  O3
# 33.6
# append
# button name:  NO2
# 15.8
# button name:  SO2
# 16
# button name:  CO
# 700
# city name:  Borivli, Maharashtra
# button name:  PM2.5
# 162
# button name:  PM10
# 248.7
# button name:  O3
# 21.6
# append
# button name:  NO2
# 40.4
# button name:  SO2
# 3.2
# button name:  CO
# 960
# city name:  Howrah, West Bengal
# button name:  PM2.5
# 156.2
# button name:  PM10
# 238
# button name:  O3
# 109.1
# append
# button name:  NO2
# 46.5
# button name:  SO2
# 37.6
# button name:  CO
# 80
# city name:  Airoli, Maharashtra
# button name:  PM2.5
# 153.6
# button name:  PM10
# 224.4
# button name:  SO2
# 9.6
# city name:  Ankleshwar, Gujarat
# button name:  PM2.5
# 153.6
# button name:  NO2
# 8.8
# city name:  Khagaul, Bihar
# button name:  PM2.5
# 152.9
# button name:  PM10
# 289
# button name:  O3
# 45.9
# append
# button name:  NO2
# 49.8
# button name:  SO2
# 12
# button name:  CO
# 1465
# country:  https://www.iqair.com/us/indonesia
# city name:  Jakarta, Jakarta
# button name:  PM2.5
# 21.8
# city name:  Medan, North Sumatra
# button name:  PM2.5
# 21.2
# city name:  Ubud, Bali
# button name:  PM2.5
# 20.9
# city name:  Bandung, West Java
# button name:  PM2.5
# 18.6
# city name:  Bekasi, West Java
# button name:  PM2.5
# 19
# city name:  Bogor, West Java
# button name:  PM2.5
# 18
# button name:  PM10
# 33
# city name:  Yogyakarta, Yogyakarta
# button name:  PM2.5
# 17
# city name:  Surabaya, East Java
# button name:  PM2.5
# 16.2
# city name:  Jimbaran, Bali
# button name:  PM2.5
# 13.8
# city name:  Malang, East Java
# button name:  PM2.5
# 10
# country:  https://www.iqair.com/us/bahrain
# city name:  Manama, Capital Governorate
# button name:  PM2.5
# 33
# country:  https://www.iqair.com/us/nepal
# city name:  Dhankuta, Eastern Region
# button name:  PM2.5
# 63.2
# button name:  PM10
# 96.2
# city name:  Kathmandu, Central Region
# button name:  PM2.5
# 31.7
# button name:  PM10
# 139.4
# button name:  O3
# 56
# append
# city name:  Bharatpur, Central Region
# button name:  PM2.5
# 31.3
# button name:  PM10
# 36.1
# city name:  Kirtipur, Central Region
# button name:  PM2.5
# 29.8
# button name:  PM10
# 31.8
# city name:  Pokhara, Western Region
# button name:  PM2.5
# 27.3
# city name:  Tulsipur, Mid Western
# button name:  PM2.5
# 25.9
# button name:  PM10
# 57
# city name:  Patan, Central Region
# button name:  PM2.5
# 25.1
# button name:  PM10
# 69.4
# city name:  Bhaktapur, Central Region
# button name:  PM2.5
# 21.1
# city name:  Nepalgunj, Mid Western
# button name:  PM2.5
# 14.7
# button name:  PM10
# 21.2
# country:  https://www.iqair.com/us/uzbekistan
# city name:  Tashkent, Toshkent Shahri
# button name:  PM2.5
# 48
# button name:  O3
# 4
# append
# country:  https://www.iqair.com/us/iraq
# city name:  Baghdad, Baghdad
# button name:  PM2.5
# 63.5
# country:  https://www.iqair.com/us/bahamas
# city name:  Governor's Harbour, Central Eleuthera
# button name:  PM2.5
# 0.7
# city name:  Nassau, New Providence
# button name:  PM2.5
# 0.8
# country:  https://www.iqair.com/us/u-s-virgin-islands
# city name:  Cruz Bay, Saint John Island
# button name:  PM2.5
# 2.2
# city name:  Charlotte Amalie, Saint Thomas Island
# button name:  PM2.5
# 1.4
# country:  https://www.iqair.com/us/iceland
# country:  https://www.iqair.com/us/finland
# city name:  Seinajoki, Southern Ostrobothnia
# button name:  PM2.5
# 13
# button name:  PM10
# 20.4
# button name:  NO2
# 27.2
# city name:  Ulvila, Satakunta
# button name:  PM2.5
# 8.6
# button name:  PM10
# 56.3
# button name:  NO2
# 6.6
# button name:  SO2
# 2.7
# city name:  Korsholm, Ostrobothnia
# button name:  PM2.5
# 10.8
# button name:  PM10
# 25.1
# button name:  NO2
# 31.1
# city name:  Vaasa, Central Ostrobothnia
# button name:  PM2.5
# 8.3
# button name:  PM10
# 10.5
# city name:  Hameenlinna, Tavastia Proper
# button name:  PM2.5
# 8
# button name:  PM10
# 3.3
# button name:  NO2
# 1.9
# city name:  Turku, Finland Proper
# button name:  PM2.5
# 8
# button name:  PM10
# 16.7
# button name:  NO2
# 11.9
# city name:  Jyvaskyla, Central Finland
# button name:  PM2.5
# 7.3
# button name:  PM10
# 21.7
# button name:  NO2
# 16.1
# city name:  Lohja, Uusimaa
# button name:  PM2.5
# 7.4
# city name:  Nurmijaervi, Uusimaa
# button name:  PM2.5
# 6.9
# city name:  Kuopio, Northern Savonia
# button name:  PM2.5
# 6.4
# button name:  PM10
# 9.1
# button name:  O3
# 18.1
# append
# button name:  NO2
# 11.4
# country:  https://www.iqair.com/us/estonia
# city name:  Sinimaee, Ida-Virumaa
# button name:  PM2.5
# 12
# button name:  PM10
# 14.1
# button name:  SO2
# 0
# city name:  Tallinn, Harjumaa
# button name:  PM2.5
# 11
# button name:  PM10
# 13.3
# button name:  O3
# 24.8
# append
# button name:  NO2
# 37.7
# button name:  SO2
# 1.8
# button name:  CO
# 290
# city name:  Narva, Ida-Virumaa
# button name:  PM2.5
# 7.9
# button name:  PM10
# 9.3
# button name:  O3
# 16.4
# append
# button name:  NO2
# 25.3
# button name:  SO2
# 0.9
# city name:  Voore, Jogevamaa
# button name:  PM2.5
# 7.1
# button name:  NO2
# 3.3
# button name:  SO2
# 0
# city name:  Sillamaee, Ida-Virumaa
# button name:  PM2.5
# 6.2
# button name:  PM10
# 6.4
# city name:  Tartu, Tartumaa
# button name:  PM2.5
# 6
# button name:  PM10
# 10.8
# button name:  NO2
# 12.7
# button name:  SO2
# 0
# button name:  CO
# 280
# city name:  Kohtla-Jaerve, Ida-Virumaa
# button name:  PM2.5
# 5.6
# button name:  PM10
# 6.4
# button name:  O3
# 4.4
# append
# button name:  NO2
# 4.9
# button name:  SO2
# 0
# city name:  Parnu Jogi, Paernumaa
# button name:  NO2
# 3.4
# button name:  SO2
# 0
# country:  https://www.iqair.com/us/sweden
# city name:  Uppsala, Uppsala län
# button name:  PM2.5
# 8
# button name:  PM10
# 9.2
# button name:  NO2
# 9.9
# city name:  Stockholm, Stockholm
# button name:  PM2.5
# 6.5
# button name:  PM10
# 8.6
# button name:  NO2
# 10.8
# city name:  Solna, Stockholm
# button name:  PM2.5
# 5.7
# city name:  Sodertalje, Stockholm
# button name:  PM2.5
# 5
# button name:  PM10
# 4.9
# button name:  NO2
# 4.9
# city name:  Kungsholmen, Stockholm
# button name:  PM2.5
# 4.7
# button name:  PM10
# 8.1
# button name:  NO2
# 13.9
# city name:  Lilla Essingen, Stockholm
# button name:  PM2.5
# 4.5
# city name:  Enkoeping, Uppsala län
# button name:  PM2.5
# 4.2
# city name:  Staffanstorp, Skane
# button name:  O3
# 37.1
# append
# city name:  Umeå, Västerbottens län
# button name:  PM2.5
# 3.5
# button name:  PM10
# 4
# button name:  NO2
# 18.9
# city name:  Lund, Skåne län
# button name:  PM2.5
# 3
# button name:  PM10
# 3.5
# button name:  O3
# 32.4
# append
# button name:  NO2
# 2.7
# country:  https://www.iqair.com/us/norway
# city name:  Baerum, Akershus
# button name:  PM2.5
# 41.4
# button name:  PM10
# 42.1
# button name:  NO2
# 40.3
# city name:  Stavanger, Rogaland
# button name:  PM2.5
# 32
# button name:  PM10
# 39.7
# button name:  NO2
# 87.1
# city name:  Bergen, Hordaland
# button name:  PM2.5
# 29.1
# button name:  PM10
# 55.5
# button name:  O3
# 1.3
# append
# button name:  NO2
# 89.2
# city name:  Porsgrunn, Telemark
# button name:  PM2.5
# 26.4
# button name:  PM10
# 35
# button name:  NO2
# 38.3
# city name:  Brevik, Telemark
# button name:  PM2.5
# 18.3
# button name:  PM10
# 28.5
# button name:  NO2
# 40
# city name:  Oslo, Oslo
# button name:  PM2.5
# 18.5
# button name:  PM10
# 13.8
# button name:  NO2
# 34.8
# button name:  CO
# 0
# city name:  Ski, Akershus
# button name:  PM2.5
# 17.2
# city name:  Lillestrom, Akershus
# button name:  PM2.5
# 14.6
# button name:  PM10
# 4.8
# button name:  NO2
# 20.9
# city name:  Kjenn, Akershus
# button name:  PM2.5
# 12.5
# button name:  PM10
# 14
# button name:  NO2
# 34
# city name:  Sandsli, Hordaland
# button name:  PM2.5
# 11.4
# button name:  PM10
# 15.9
# button name:  NO2
# 40.5
# country:  https://www.iqair.com/us/new-zealand
# city name:  Masterton, Wellington
# button name:  PM2.5
# 25.7
# button name:  PM10
# 3.7
# button name:  NO2
# 0.8
# button name:  CO
# 100
# city name:  Napier, Hawke's Bay
# button name:  PM2.5
# 11.4
# button name:  PM10
# 9.7
# city name:  Wellington City, Wellington
# button name:  PM2.5
# 8.5
# button name:  PM10
# 13.5
# button name:  NO2
# 7.3
# city name:  Gisborne, Gisborne
# button name:  PM2.5
# 7.6
# button name:  PM10
# 24.5
# city name:  Awatoto, Hawke's Bay
# button name:  PM2.5
# 6.7
# button name:  PM10
# 24.3
# city name:  Mosgiel, Otago
# button name:  PM10
# 27.2
# city name:  Hastings, Hawke's Bay
# button name:  PM2.5
# 5.5
# button name:  PM10
# 3.1
# city name:  Arrowtown, Otago
# button name:  PM10
# 18.6
# city name:  Otorohanga, Waikato
# button name:  PM10
# 17.4
# city name:  Wainuiomata, Wellington
# button name:  PM2.5
# 3.8
# button name:  PM10
# 5.7
# country:  https://www.iqair.com/us/canada
# city name:  Simcoe, Ontario
# button name:  PM2.5
# 36.7
# city name:  Woodstock, Ontario
# button name:  PM2.5
# 30.1
# city name:  Saint-jean-baptiste, Quebec
# button name:  PM2.5
# 26
# button name:  O3
# 15
# append
# button name:  NO2
# 2
# button name:  SO2
# 1
# city name:  Chenier, Quebec
# button name:  PM2.5
# 25
# button name:  O3
# 12
# append
# button name:  NO2
# 3
# button name:  SO2
# 1
# city name:  Hochelaga, Quebec
# button name:  PM2.5
# 25
# button name:  O3
# 13
# append
# button name:  NO2
# 3
# button name:  SO2
# 1
# city name:  York, Quebec
# button name:  PM2.5
# 24
# button name:  O3
# 14
# append
# button name:  NO2
# 2
# city name:  Houston, British Columbia
# button name:  PM2.5
# 23.8
# button name:  PM10
# 13
# city name:  Dawson City, Yukon
# button name:  PM2.5
# 23.1
# city name:  Windsor, Ontario
# button name:  PM2.5
# 21.5
# button name:  O3
# 16
# append
# button name:  NO2
# 25.1
# button name:  SO2
# 0
# button name:  CO
# 297.7
# city name:  Kitchener, Ontario
# button name:  PM2.5
# 21
# button name:  O3
# 40
# append
# button name:  NO2
# 16
# country:  https://www.iqair.com/us/australia
# city name:  Geraldton, Western Australia
# button name:  PM2.5
# 11.6
# button name:  PM10
# 379
# city name:  Wyong, New South Wales
# button name:  PM2.5
# 77.4
# button name:  PM10
# 2
# button name:  NO2
# 3.8
# button name:  SO2
# 2.6
# button name:  CO
# 4
# city name:  Orange, New South Wales
# button name:  PM2.5
# 51.2
# button name:  PM10
# 30.6
# city name:  Shellharbour, New South Wales
# button name:  PM2.5
# 49.3
# button name:  PM10
# 12.8
# button name:  NO2
# 5.6
# button name:  SO2
# 2.6
# city name:  Rouse Hill, New South Wales
# button name:  PM2.5
# 48.4
# button name:  PM10
# 82.9
# button name:  O3
# 6
# append
# button name:  NO2
# 3.8
# button name:  SO2
# 2.6
# city name:  Coffs Harbour, New South Wales
# button name:  PM2.5
# 30.8
# button name:  PM10
# 14
# button name:  NO2
# 1.9
# button name:  CO
# 18.2
# city name:  Beresfield, New South Wales
# button name:  PM2.5
# 13.8
# button name:  PM10
# 18.6
# button name:  O3
# 4
# append
# button name:  NO2
# 3.8
# button name:  SO2
# 2.6
# city name:  Kembla Grange, New South Wales
# button name:  PM2.5
# 12.8
# button name:  PM10
# 63.9
# button name:  O3
# 2
# append
# button name:  NO2
# 1.9
# city name:  Swan, Western Australia
# button name:  PM2.5
# 14
# button name:  PM10
# 55
# button name:  NO2
# 5.6
# city name:  Coonabarabran, New South Wales
# button name:  PM2.5
# 10.1
# finish

# %%
data = {'City': city_names, 'AQI': aqi_values, 'PM2.5': PM25, 'PM10': PM10, 'O3': O3, 'NO2': NO2, 'SO2': SO2, 'CO': CO}
df = pd.DataFrame(data)
df.to_csv("data.csv")

# %%
print(PM25)
# Out:
# ['79.8', '68.3', '50.5', '44.6', '3', '105.9', '74.3', '72.1', '50.8', '90', '33', '31.9', '30.7', '30', '26.8', '36', '30.5', '18', '12', '12', '6.2', '5', '1', 'NULL', '10.2', '255', '200.5', '187.5', '172', '168', '162', '156.2', '153.6', '153.6', '152.9', '21.8', '21.2', '20.9', '18.6', '19', '18', '17', '16.2', '13.8', '10', '33', '63.2', '31.7', '31.3', '29.8', '27.3', '25.9', '25.1', '21.1', '14.7', '48', '63.5', '0.7', '0.8', '2.2', '1.4', '13', '8.6', '10.8', '8.3', '8', '8', '7.3', '7.4', '6.9', '6.4', '12', '11', '7.9', '7.1', '6.2', '6', '5.6', 'NULL', '8', '6.5', '5.7', '5', '4.7', '4.5', '4.2', 'NULL', '3.5', '3', '41.4', '32', '29.1', '26.4', '18.3', '18.5', '17.2', '14.6', '12.5', '11.4', '25.7', '11.4', '8.5', '7.6', '6.7', 'NULL', '5.5', 'NULL', 'NULL', '3.8', '36.7', '30.1', '26', '25', '25', '24', '23.8', '23.1', '21.5', '21', '11.6', '77.4', '51.2', '49.3', '48.4', '30.8', '13.8', '12.8', '14', '10.1']

# %%
print(PM10)
# Out:
# ['NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '72', '52', '14', '16', 'NULL', '9', '19', 'NULL', 'NULL', 'NULL', '277', '225.9', 'NULL', '202', '248.7', '238', '224.4', 'NULL', '289', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '33', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '96.2', '139.4', '36.1', '31.8', 'NULL', '57', '69.4', 'NULL', '21.2', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '20.4', '56.3', '25.1', '10.5', '3.3', '16.7', '21.7', 'NULL', 'NULL', '9.1', '14.1', '13.3', '9.3', 'NULL', '6.4', '10.8', '6.4', 'NULL', '9.2', '8.6', 'NULL', '4.9', '8.1', 'NULL', 'NULL', 'NULL', '4', '3.5', '42.1', '39.7', '55.5', '35', '28.5', '13.8', 'NULL', '4.8', '14', '15.9', '3.7', '9.7', '13.5', '24.5', '24.3', '27.2', '3.1', '18.6', '17.4', '5.7', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '13', 'NULL', 'NULL', 'NULL', '379', '2', '30.6', '12.8', '82.9', '14', '18.6', '63.9', '55', 'NULL']

# %%
print(O3)
# Out:
# ['NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '10.5', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '6', '11', '17', '58.8', '33.6', '21.6', '109.1', 'NULL', 'NULL', '45.9', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '56', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '4', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '18.1', 'NULL', '24.8', '16.4', 'NULL', 'NULL', 'NULL', '4.4', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '37.1', 'NULL', '32.4', 'NULL', 'NULL', '1.3', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '15', '12', '13', '14', 'NULL', 'NULL', '16', '40', 'NULL', 'NULL', 'NULL', 'NULL', '6', 'NULL', '4', '2', 'NULL', 'NULL']

# %%
print(NO2)
# Out:
# ['NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '7', '7', '3', '6', 'NULL', '5', '2', 'NULL', 'NULL', '2.4', '58.8', '27.2', '108.4', '15.8', '40.4', '46.5', 'NULL', '8.8', '49.8', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '27.2', '6.6', '31.1', 'NULL', '1.9', '11.9', '16.1', 'NULL', 'NULL', '11.4', 'NULL', '37.7', '25.3', '3.3', 'NULL', '12.7', '4.9', '3.4', '9.9', '10.8', 'NULL', '4.9', '13.9', 'NULL', 'NULL', 'NULL', '18.9', '2.7', '40.3', '87.1', '89.2', '38.3', '40', '34.8', 'NULL', '20.9', '34', '40.5', '0.8', 'NULL', '7.3', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '2', '3', '3', '2', 'NULL', 'NULL', '25.1', '16', 'NULL', '3.8', 'NULL', '5.6', '3.8', '1.9', '3.8', '1.9', '5.6', 'NULL']

# %%
print(CO)
# Out:
# ['NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '2', 'NULL', 'NULL', 'NULL', 'NULL', '2', 'NULL', 'NULL', 'NULL', 'NULL', '2660', '1410', '2590', '700', '960', '80', 'NULL', 'NULL', '1465', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '290', 'NULL', 'NULL', 'NULL', '280', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 0, 'NULL', 'NULL', 'NULL', 'NULL', '100', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '297.7', 'NULL', 'NULL', '4', 'NULL', 'NULL', 'NULL', '18.2', 'NULL', 'NULL', 'NULL', 'NULL']

# %%
#thu thap them du lieu tu 1 so quoc gia khac
country_links = []
city_names = []
aqi_values = []
PM25 = []
PM10 = []
O3 = []
NO2 = []
SO2 = []
CO = []

list_countries_str = 'japan china canada vietnam uk france germany thailand switzerland findland greece brazil russia philippines myanmar laos usa bulgaria malaysia peru serbia slovakia spain syria'
list_countries = list_countries_str.split()

for country in list_countries:
    #lay ra duong link dan den cac quoc gia trong top
    country_link = 'https://www.iqair.com/' + country
    country_links.append(country_link)
    
for country_link in country_links:
    print('country: ', country_link)
    while True:        
        driver.get(country_link)
        #lay ra mot so thanh pho cua country
        if not check_element_exist('ranking__table'):
            break
            
        ranking_table = driver.find_element_by_class_name('ranking__table')
        cities = ranking_table.find_elements_by_tag_name('a')
        
        remain_city = False #kiem tra xem con thanh pho nao chua duoc duyet hay khong
        for city in cities:
            if city.text not in city_names:
                remain_city = True
                
                city_names.append(city.text)
                print('city name: ', city.text)
                city_link = city.get_attribute('href')
                driver.get(city_link)
        
                #lay ra chi so AQI
                if not check_element_exist('aqi-value__value'):
                    aqi_values.append('NULL')
                    PM25.append('NULL')
                    PM10.append('NULL')
                    O3.append('NULL')
                    NO2.append('NULL')
                    SO2.append('NULL')
                    CO.append('NULL')
                else:
                    aqi = driver.find_element_by_class_name('aqi-value__value')
                    aqi_values.append(aqi.text)
                    #lay ra danh sach cac button chi so
                    button_board = driver.find_element_by_class_name('pollutant-history-type-buttons')
                    buttons = button_board.find_elements_by_tag_name('button')
                    #bo button AQI
                    buttons = buttons[1:]
                    for button in buttons:
                        print('button name: ', button.text)
                        #click vao tung button
                        button.click()
                        #lay chi so cuoi cung cua bieu do trong button
                        chart = driver.find_element_by_class_name('highcharts-series-group')
                        cols = chart.find_elements_by_tag_name('rect')
                        element_to_hover = cols[-1]
                        ActionChains(driver).move_to_element(element_to_hover).perform()
                        values = driver.find_elements_by_tag_name('tspan')
                        if len(values) == 1:
                            index_value = 0
                        else:
                            index_value = values[-2].text
                            if not is_number(index_value):
                                index_value = 0
                                
                        print(index_value)
                        
                        if button.text == 'PM2.5':
                            PM25.append(index_value)
                        elif button.text =='PM10':
                            PM10.append(index_value)
                        elif button.text == 'O3':
                            O3.append(index_value)
                        elif button.text == 'NO2':
                            NO2.append(index_value)
                        elif button.text == 'SO2':
                            SO2.append(index_value)
                        elif button.text == 'CO':
                            CO.append(index_value)
                        
                    len_aqi_values = len(aqi_values)
                    if len(PM25) < len_aqi_values:
                        PM25.append('NULL')
                    if len(PM10) < len_aqi_values:
                        PM10.append('NULL')
                    if len(O3) < len_aqi_values:
                        O3.append('NULL')
                    if len(NO2) < len_aqi_values:
                        NO2.append('NULL')
                    if len(SO2) < len_aqi_values:
                        SO2.append('NULL')
                    if len(CO) < len_aqi_values:
                        CO.append('NULL')
                    
                break
        #neu tat ca cac thanh pho da duoc duyet thi ket thuc
        if remain_city == False:
            break
print('finish')
# Out:
# country:  https://www.iqair.com/japan
# city name:  Tsubaki, Chiba
# button name:  PM2.5
# 43
# button name:  NO2
# 3.8
# city name:  Kohokudai, Chiba
# button name:  PM2.5
# 24
# button name:  NO2
# 13.2
# city name:  Shimoiino, Chiba
# button name:  PM2.5
# 35
# button name:  NO2
# 3.8
# button name:  SO2
# 2.6
# city name:  Kukichuo, Saitama
# button name:  PM2.5
# 32
# button name:  PM10
# 15
# button name:  NO2
# 52.6
# city name:  Nagayama 1 Jo, Hokkaido
# button name:  PM2.5
# 28
# button name:  PM10
# 29
# button name:  NO2
# 73.3
# city name:  Nakamuraminami, Ibaraki
# button name:  PM2.5
# 28
# button name:  PM10
# 21
# button name:  NO2
# 56.4
# city name:  Yachimata, Chiba
# button name:  PM2.5
# 28
# button name:  NO2
# 3.8
# city name:  Fujimi, Yamanashi
# button name:  PM2.5
# 27
# button name:  PM10
# 38
# button name:  NO2
# 39.5
# button name:  SO2
# 2.6
# city name:  Ishikawa, Ibaraki
# button name:  PM2.5
# 27
# button name:  PM10
# 11
# button name:  NO2
# 22.6
# button name:  SO2
# 2.6
# city name:  Kofu, Yamanashi
# button name:  PM2.5
# 27
# button name:  PM10
# 14.5
# button name:  NO2
# 39.5
# button name:  CO
# 572.5
# country:  https://www.iqair.com/china
# city name:  Ili, Xinjiang
# button name:  PM2.5
# 328
# button name:  PM10
# 341
# button name:  O3
# 11
# button name:  NO2
# 85.5
# button name:  SO2
# 46
# button name:  CO
# 7900
# city name:  Wujiaqu, Xinjiang
# button name:  PM2.5
# 163
# button name:  PM10
# 220
# button name:  O3
# 6
# button name:  NO2
# 1
# button name:  SO2
# 5.5
# city name:  Shihezi, Xinjiang
# button name:  PM2.5
# 141.5
# button name:  PM10
# 149
# button name:  O3
# 11
# button name:  NO2
# 73
# button name:  SO2
# 6
# button name:  CO
# 2400
# city name:  Yunfu, Guangdong
# button name:  PM2.5
# 116
# button name:  PM10
# 112
# button name:  O3
# 47.5
# button name:  NO2
# 24.5
# button name:  SO2
# 10
# button name:  CO
# 1050
# city name:  Zhaoqing, Guangdong
# button name:  PM2.5
# 115
# button name:  PM10
# 131.5
# button name:  O3
# 40
# button name:  NO2
# 27
# button name:  SO2
# 8.5
# button name:  CO
# 1100
# city name:  Aksu, Xinjiang
# button name:  PM2.5
# 68
# button name:  PM10
# 313.5
# button name:  O3
# 10.5
# button name:  NO2
# 45.5
# button name:  SO2
# 10
# button name:  CO
# 2050
# city name:  Yulin, Guangxi
# button name:  PM2.5
# 108
# button name:  PM10
# 120
# button name:  O3
# 51
# button name:  NO2
# 24.5
# button name:  SO2
# 5
# button name:  CO
# 1150
# city name:  Beihai, Guangxi
# button name:  PM2.5
# 103
# button name:  PM10
# 91.5
# button name:  O3
# 42
# button name:  NO2
# 19
# button name:  SO2
# 8
# button name:  CO
# 1000
# city name:  Changzhou Qu, Guangxi
# button name:  PM2.5
# 103
# button name:  PM10
# 92
# button name:  O3
# 25
# button name:  NO2
# 29
# button name:  SO2
# 5
# button name:  CO
# 1400
# city name:  Zhanjiang, Guangdong
# button name:  PM2.5
# 103.5
# button name:  PM10
# 117
# button name:  O3
# 50
# button name:  NO2
# 30
# button name:  SO2
# 23
# button name:  CO
# 1050
# country:  https://www.iqair.com/canada
# city name:  Otterburn Park, Quebec
# button name:  PM2.5
# 33.9
# city name:  Dawson City, Yukon
# button name:  PM2.5
# 34.4
# city name:  Revelstoke, British Columbia
# button name:  PM2.5
# 26.3
# city name:  North Cowichan, British Columbia
# button name:  PM2.5
# 26.2
# city name:  Golden, British Columbia
# button name:  PM2.5
# 32.6
# button name:  PM10
# 14.6
# city name:  Saint-Bruno-de-Montarville, Quebec
# button name:  PM2.5
# 17.6
# city name:  Whitehorse, Yukon
# button name:  PM2.5
# 25.2
# city name:  Winnipeg, Manitoba
# button name:  PM2.5
# 20.2
# button name:  O3
# 4.8
# button name:  NO2
# 6.5
# city name:  Campbell River, British Columbia
# button name:  PM2.5
# 22.4
# city name:  Norman Wells, Northwest Territories
# button name:  PM2.5
# 11.3
# button name:  PM10
# 91.4
# button name:  NO2
# 2.4
# button name:  SO2
# 14.4
# country:  https://www.iqair.com/vietnam
# city name:  Ha Tinh, Tinh Ha Tinh
# button name:  PM2.5
# 119.6
# city name:  Phuc Yen, Tinh Vinh Phuc
# button name:  PM2.5
# 117.8
# button name:  PM10
# 193.5
# city name:  Luong Son, Tinh Hoa Binh
# button name:  PM2.5
# 111.3
# button name:  PM10
# 189.5
# city name:  Thua, Tinh Bac Ninh
# button name:  PM2.5
# 102.5
# button name:  PM10
# 116.5
# button name:  NO2
# 19.6
# button name:  SO2
# 1.5
# button name:  CO
# 0
# city name:  Hanoi, Hanoi
# button name:  PM2.5
# 115.1
# button name:  PM10
# 136.6
# button name:  O3
# 0
# button name:  NO2
# 22.7
# button name:  SO2
# 4.2
# button name:  CO
# 1190.7
# city name:  Bac Ninh, Tinh Bac Ninh
# button name:  PM2.5
# 92.5
# button name:  PM10
# 111
# button name:  SO2
# 45.5
# city name:  Cau Giay, Hanoi
# button name:  PM2.5
# 98.3
# button name:  PM10
# 136.3
# button name:  NO2
# 10.1
# button name:  CO
# 0.8
# city name:  Thanh Pho Thai Nguyen, Tinh Thai Nguyen
# button name:  PM2.5
# 103.8
# button name:  SO2
# 3.7
# button name:  CO
# 1.1
# city name:  Hai BaTrung, Hanoi
# button name:  PM2.5
# 116.9
# button name:  PM10
# 131.8
# button name:  NO2
# 14.4
# button name:  CO
# 694.6
# city name:  Nhu Quynh, Tinh Hung Yen
# button name:  PM2.5
# 91.5
# button name:  PM10
# 118.5
# button name:  O3
# 0
# button name:  NO2
# 34.4
# button name:  SO2
# 8.6
# button name:  CO
# 0
# country:  https://www.iqair.com/uk
# city name:  Nantwich, England
# button name:  PM2.5
# 43.7
# city name:  Warrington, England
# button name:  PM2.5
# 41
# button name:  PM10
# 50.2
# button name:  NO2
# 45.1
# city name:  Wigan, England
# button name:  PM2.5
# 40.5
# button name:  PM10
# 46.2
# button name:  O3
# 1.8
# button name:  NO2
# 13.8
# city name:  Haydock, England
# button name:  PM2.5
# 40
# button name:  PM10
# 46.4
# city name:  Leigh, England
# button name:  PM2.5
# 38
# button name:  PM10
# 45.4
# button name:  NO2
# 49
# city name:  Ringwood, England
# button name:  PM2.5
# 37.6
# city name:  Salford, England
# button name:  PM2.5
# 35.9
# city name:  Manchester, England
# button name:  PM2.5
# 33.8
# button name:  PM10
# 36.6
# button name:  O3
# 1.6
# button name:  NO2
# 74.4
# button name:  SO2
# 4
# city name:  Cambridge, England
# button name:  PM2.5
# 31.7
# button name:  PM10
# 7.1
# button name:  NO2
# 13.3
# city name:  Weymouth, England
# button name:  PM2.5
# 31.9
# country:  https://www.iqair.com/france
# city name:  Talence, Nouvelle-Aquitaine
# button name:  PM2.5
# 61
# button name:  PM10
# 63
# button name:  O3
# 2
# button name:  NO2
# 25
# city name:  Nantes, Pays de la Loire
# button name:  PM2.5
# 49
# button name:  PM10
# 54
# button name:  O3
# 1.5
# button name:  NO2
# 19
# button name:  SO2
# 2
# city name:  Tarbes, Occitanie
# button name:  PM2.5
# 48.7
# button name:  PM10
# 50.8
# button name:  O3
# 2.2
# button name:  NO2
# 25.8
# city name:  Toulouse, Occitanie
# button name:  PM2.5
# 47
# button name:  PM10
# 55.5
# button name:  O3
# 4.9
# button name:  NO2
# 30.2
# city name:  Lorient, Brittany
# button name:  PM2.5
# 45.1
# button name:  PM10
# 56.8
# button name:  O3
# 2
# button name:  NO2
# 25.6
# city name:  Bassens, Nouvelle-Aquitaine
# button name:  PM2.5
# 45
# button name:  PM10
# 48
# button name:  O3
# 3
# button name:  NO2
# 21
# button name:  SO2
# 1
# city name:  Perigueux, Nouvelle-Aquitaine
# button name:  PM2.5
# 45
# button name:  PM10
# 47
# button name:  O3
# 2
# button name:  NO2
# 11
# city name:  Biars-sur-Cere, Occitanie
# button name:  PM2.5
# 44
# button name:  PM10
# 57.8
# button name:  O3
# 0
# button name:  NO2
# 23.3
# city name:  Bouguenais, Pays de la Loire
# button name:  PM2.5
# 44
# button name:  PM10
# 65
# button name:  NO2
# 19
# button name:  SO2
# 1
# city name:  Saint-Nazaire, Pays de la Loire
# button name:  PM2.5
# 44
# button name:  PM10
# 45
# button name:  O3
# 4
# button name:  NO2
# 16
# button name:  SO2
# 1
# country:  https://www.iqair.com/germany
# city name:  Oberaudorf, Bavaria
# button name:  PM2.5
# 26.5
# button name:  PM10
# 28.4
# button name:  NO2
# 24.6
# city name:  Meiderich, Nordrhein-Westfalen
# button name:  PM2.5
# 25.1
# city name:  Schongau, Bavaria
# button name:  PM2.5
# 24.5
# city name:  Ettlingen, Baden-Wuerttemberg
# button name:  PM2.5
# 23.6
# city name:  Eppelheim, Baden-Wuerttemberg
# button name:  PM2.5
# 23.2
# city name:  Neuenburg, Baden-Wuerttemberg
# button name:  PM2.5
# 23
# button name:  PM10
# 24
# button name:  O3
# 15
# city name:  Weil am Rhein, Baden-Wuerttemberg
# button name:  PM2.5
# 23
# button name:  PM10
# 24
# button name:  O3
# 3
# city name:  Mainz, Rheinland-Pfalz
# button name:  PM2.5
# 21.3
# button name:  PM10
# 16
# button name:  O3
# 35
# button name:  NO2
# 11
# button name:  SO2
# 1
# button name:  CO
# 240
# city name:  Rottach-Egern, Bavaria
# button name:  PM2.5
# 21.2
# city name:  Dresden, Saxony
# button name:  PM2.5
# 20
# button name:  PM10
# 9.5
# button name:  O3
# 30
# button name:  NO2
# 9
# button name:  SO2
# 0
# country:  https://www.iqair.com/thailand
# city name:  Sam Phran, Nakhon Pathom
# button name:  PM2.5
# 120.2
# city name:  Nakhon Pathom, Nakhon Pathom
# button name:  PM2.5
# 65.2
# city name:  Samut Sakhon, Samut Sakhon
# button name:  PM2.5
# 44.2
# button name:  PM10
# 180
# button name:  O3
# 104
# button name:  NO2
# 52.6
# button name:  SO2
# 48.5
# button name:  CO
# 1293.9
# city name:  Bang Khon Thi, Samut Songkhram
# button name:  PM2.5
# 85.8
# city name:  Phra Samut Chedi, Samut Prakan
# button name:  PM2.5
# 80
# button name:  PM10
# 84
# button name:  O3
# 58
# button name:  NO2
# 60.2
# button name:  SO2
# 7.9
# button name:  CO
# 366.4
# city name:  Nong Khaem, Bangkok
# button name:  PM2.5
# 77
# button name:  PM10
# 99
# city name:  Nakhon Chai Si, Nakhon Pathom
# button name:  PM2.5
# 75
# button name:  PM10
# 114
# button name:  O3
# 44
# button name:  NO2
# 37.6
# button name:  SO2
# 10.5
# button name:  CO
# 893.1
# city name:  Samut Songkhram, Samut Songkhram
# button name:  PM2.5
# 81.2
# city name:  San Kamphaeng, Chiang Mai
# button name:  PM2.5
# 42.6
# city name:  Chiang Rai, Chiang Rai
# button name:  PM2.5
# 59.1
# button name:  PM10
# 28.5
# button name:  O3
# 22
# button name:  NO2
# 3.8
# button name:  CO
# 681.3
# country:  https://www.iqair.com/switzerland
# city name:  Ecublens, Vaud
# button name:  PM2.5
# 43.2
# city name:  Dubendorf, Zurich
# button name:  PM2.5
# 36.3
# button name:  PM10
# 18
# button name:  O3
# 26
# button name:  NO2
# 28
# button name:  SO2
# 1
# city name:  Liestal, Basel-Landschaft
# button name:  PM2.5
# 27.5
# city name:  Rhaezuens, Grisons
# button name:  PM2.5
# 31
# button name:  PM10
# 32.1
# button name:  O3
# 6.6
# city name:  Rotkreuz, Zug
# button name:  PM2.5
# 27.5
# city name:  Chur, Grisons
# button name:  PM2.5
# 24.5
# button name:  PM10
# 31.5
# button name:  O3
# 19.2
# button name:  NO2
# 34.3
# city name:  Dietikon, Zurich
# button name:  PM2.5
# 24.5
# city name:  Richterswil / Dorfkern, Zurich
# button name:  PM2.5
# 23.3
# city name:  Binningen, Basel-Landschaft
# button name:  PM2.5
# 23
# button name:  PM10
# 24
# button name:  O3
# 8
# city name:  Harkingen, Solothurn
# button name:  PM2.5
# 21
# button name:  PM10
# 42
# button name:  O3
# 6
# country:  https://www.iqair.com/findland
# country:  https://www.iqair.com/greece
# city name:  Meligalas, Peloponnese
# button name:  PM2.5
# 56.8
# city name:  Messini, Peloponnese
# button name:  PM2.5
# 54.9
# city name:  Palaio Faliro, Attica
# button name:  PM2.5
# 47.3
# city name:  Vrachnaiika, West Greece
# button name:  PM2.5
# 45.2
# city name:  Agios Ioannis Rentis, Attica
# button name:  PM2.5
# 40.7
# city name:  Peristeri, Attica
# button name:  PM2.5
# 34.7
# city name:  Athens, Attica
# button name:  PM2.5
# 29.2
# city name:  Piraeus, Attica
# button name:  PM2.5
# 29.3
# city name:  Agia Varvara, Attica
# button name:  PM2.5
# 24.3
# city name:  Nikaia, Attica
# button name:  PM2.5
# 23.8
# country:  https://www.iqair.com/brazil
# city name:  Sao Bernardo do Campo, Sao Paulo
# button name:  PM2.5
# 17
# button name:  O3
# 22
# city name:  Santa Gertrudes, Sao Paulo
# button name:  PM2.5
# 10
# button name:  PM10
# 68
# city name:  Sao Caetano do Sul, Sao Paulo
# button name:  PM2.5
# 13
# button name:  PM10
# 19
# button name:  O3
# 42
# button name:  NO2
# 35
# button name:  SO2
# 1
# city name:  Guarulhos, Sao Paulo
# button name:  PM2.5
# 11
# button name:  PM10
# 13
# button name:  O3
# 41
# button name:  NO2
# 23
# button name:  SO2
# 1
# button name:  CO
# 572.5
# city name:  Cubatao, Sao Paulo
# button name:  PM10
# 48
# button name:  NO2
# 43
# button name:  SO2
# 3
# city name:  Campinas, Sao Paulo
# button name:  PM2.5
# 10
# button name:  PM10
# 11
# button name:  NO2
# 19
# city name:  Maua, Sao Paulo
# button name:  PM2.5
# 9
# button name:  PM10
# 11
# button name:  O3
# 28
# button name:  NO2
# 36
# button name:  SO2
# 2
# city name:  Sao Jose do Rio Preto, Sao Paulo
# button name:  PM2.5
# 9
# button name:  PM10
# 17
# button name:  O3
# 36
# button name:  NO2
# 31
# city name:  Pianco, Paraiba
# button name:  PM2.5
# 8.8
# city name:  Boa Vista, Roraima
# button name:  PM2.5
# 7.5
# country:  https://www.iqair.com/russia
# city name:  Solnechnyy, Krasnoyarsk Krai
# button name:  PM2.5
# 150
# button name:  NO2
# 160
# button name:  SO2
# 60
# button name:  CO
# 140
# city name:  Zyryanka, Chukot
# button name:  PM2.5
# 22
# city name:  Balashikha, Moscow Oblast
# button name:  PM2.5
# 31.8
# city name:  Krasnoyarsk, Krasnoyarsk Krai
# button name:  PM2.5
# 17.4
# button name:  NO2
# 160
# button name:  SO2
# 50
# button name:  CO
# 160
# city name:  Magnitogorsk, Chelyabinsk
# button name:  PM2.5
# 27.2
# city name:  Serpukhov, Moscow Oblast
# button name:  PM2.5
# 18.9
# city name:  Krasnodar, Krasnodarskiy
# button name:  PM2.5
# 15
# city name:  Moscow, Moscow
# button name:  PM2.5
# 34.1
# button name:  PM10
# 15
# button name:  O3
# 24.3
# button name:  NO2
# 34.7
# button name:  SO2
# 1.6
# button name:  CO
# 200
# city name:  Berezovka, Krasnoyarsk Krai
# button name:  PM2.5
# 130
# button name:  NO2
# 270
# button name:  SO2
# 20
# button name:  CO
# 80
# city name:  Kamensk-Shakhtinskiy, Rostov
# button name:  PM2.5
# 10.2
# country:  https://www.iqair.com/philippines
# city name:  Bulacan, Central Luzon
# button name:  PM2.5
# 12.3
# city name:  Puerto Princesa, Mimaropa
# button name:  PM2.5
# 19
# button name:  PM10
# 35
# city name:  Makati, National Capital Region
# button name:  PM2.5
# 24.9
# city name:  Davao City, Davao
# button name:  PM2.5
# 16
# button name:  PM10
# 26.5
# button name:  NO2
# 13
# city name:  Pasig City, National Capital Region
# button name:  PM2.5
# 12.3
# city name:  Butuan, Caraga
# button name:  PM2.5
# 12
# button name:  PM10
# 18
# city name:  Balanga, Central Luzon
# button name:  PM2.5
# 19.2
# city name:  Quezon City, National Capital Region
# button name:  PM2.5
# 7.3
# city name:  San Juan, National Capital Region
# button name:  PM2.5
# 10.8
# city name:  Mandaluyong, National Capital Region
# button name:  PM2.5
# 4.8
# country:  https://www.iqair.com/myanmar
# city name:  Mandalay, Mandalay
# button name:  PM2.5
# 62.9
# city name:  Yangon, Yangon
# button name:  PM2.5
# 62.1
# button name:  O3
# 4
# city name:  Syriam, Yangon
# button name:  PM2.5
# 38.8
# country:  https://www.iqair.com/laos
# city name:  Vientiane, Vientiane
# button name:  PM2.5
# 21
# country:  https://www.iqair.com/usa
# city name:  Tuolumne City, California
# button name:  PM2.5
# 64.8
# city name:  La Jolla Shores, California
# button name:  PM2.5
# 54.7
# city name:  Peaceful Valley, Washington
# button name:  PM2.5
# 35.1
# city name:  Fort Jones, California
# button name:  PM2.5
# 55.5
# city name:  Hanford, California
# button name:  PM2.5
# 49
# button name:  PM10
# 75.1
# button name:  O3
# 2
# button name:  NO2
# 39.5
# city name:  Chippewa Falls, Wisconsin
# button name:  PM2.5
# 44.2
# city name:  Visalia, California
# button name:  PM2.5
# 39
# button name:  O3
# 38
# city name:  Las Vegas, New Mexico
# button name:  PM2.5
# 42.8
# city name:  Sparta, Wisconsin
# button name:  PM2.5
# 52.3
# city name:  Reedley, California
# button name:  PM2.5
# 43.2
# country:  https://www.iqair.com/bulgaria
# city name:  Plovdiv, Plovdiv
# button name:  PM2.5
# 86
# button name:  PM10
# 95.8
# button name:  O3
# 4.1
# button name:  SO2
# 6.5
# button name:  CO
# 0
# city name:  Vidin, Vidin
# button name:  PM2.5
# 39
# button name:  PM10
# 46.4
# city name:  Nesebar, Burgas
# button name:  PM2.5
# 28
# button name:  PM10
# 38.8
# button name:  NO2
# 11.5
# button name:  SO2
# 2.2
# city name:  Ruse, Ruse
# button name:  PM2.5
# 26.4
# button name:  PM10
# 27.6
# button name:  O3
# 3.6
# button name:  CO
# 0
# city name:  Sliven, Sliven
# button name:  PM2.5
# 22
# button name:  PM10
# 24.2
# city name:  Devnya, Varna
# button name:  PM2.5
# 20
# button name:  PM10
# 27.2
# button name:  O3
# 0
# button name:  NO2
# 1.3
# button name:  CO
# 0
# city name:  Kardzhali, Kardzhali
# button name:  PM2.5
# 20
# button name:  PM10
# 26.2
# city name:  Varna, Varna
# button name:  PM2.5
# 19.4
# button name:  PM10
# 20.3
# button name:  O3
# 5.8
# button name:  CO
# 0
# city name:  Stara Zagora, Stara Zagora
# button name:  PM2.5
# 17
# button name:  PM10
# 21.1
# button name:  NO2
# 18
# button name:  SO2
# 6.5
# button name:  CO
# 0
# city name:  Sofia, Sofia
# button name:  PM2.5
# 14.9
# button name:  PM10
# 27.4
# button name:  O3
# 27.5
# button name:  NO2
# 22.9
# button name:  SO2
# 5.5
# button name:  CO
# 0
# country:  https://www.iqair.com/malaysia
# city name:  Petaling Jaya, Selangor
# button name:  PM2.5
# 35.4
# city name:  Klang, Selangor
# button name:  PM2.5
# 25
# city name:  Kuala Langat, Selangor
# button name:  PM2.5
# 24.3
# city name:  Banting, Selangor
# button name:  PM2.5
# 22.5
# city name:  Nilai, Negeri Sembilan
# button name:  PM2.5
# 21.2
# city name:  Seri Manjung, Perak
# button name:  PM2.5
# 18.6
# city name:  Shah Alam, Selangor
# button name:  PM2.5
# 18.6
# city name:  Kuala Lumpur, Kuala Lumpur
# button name:  PM2.5
# 10.2
# city name:  Prai, Penang
# button name:  PM2.5
# 16
# city name:  Putrajaya, Putrajaya
# button name:  PM2.5
# 16
# country:  https://www.iqair.com/peru
# city name:  San Juan de Lurigancho, Lima
# button name:  PM2.5
# 20.6
# button name:  O3
# 4.3
# button name:  SO2
# 9.9
# button name:  CO
# 1
# city name:  Trujillo, La Libertad
# button name:  PM2.5
# 14.3
# city name:  Lima, Lima
# button name:  PM2.5
# 10.5
# button name:  PM10
# 14.1
# city name:  HUACHIPA, Lima
# button name:  SO2
# 50.4
# button name:  CO
# 46
# city name:  El Tambo, Junin
# button name:  PM2.5
# 5.1
# city name:  Cusco, Cusco
# button name:  PM2.5
# 4.1
# city name:  Chupaca, Junin
# button name:  PM2.5
# 3
# city name:  Santa Anita, Lima
# button name:  NO2
# 3.1
# button name:  SO2
# 17.7
# city name:  Puerto Maldonado, Madre de Dios
# button name:  PM2.5
# 0.5
# city name:  Inapari, Madre de Dios
# country:  https://www.iqair.com/serbia
# city name:  Valjevo, Central Serbia
# button name:  PM2.5
# 59.7
# button name:  PM10
# 32
# button name:  NO2
# 40.8
# button name:  SO2
# 8.3
# city name:  Novi Pazar, Central serb
# button name:  PM2.5
# 51.7
# button name:  PM10
# 52.7
# button name:  O3
# 19.3
# button name:  NO2
# 15.9
# button name:  SO2
# 11.1
# city name:  Novi Sad, Autonomna Pokrajina Vojvodina
# button name:  PM2.5
# 19.7
# button name:  PM10
# 21.1
# button name:  NO2
# 31.9
# button name:  SO2
# 10.9
# city name:  Pancevo, Autonomna Pokrajina Vojvodina
# button name:  PM2.5
# 15.4
# button name:  PM10
# 17.8
# button name:  O3
# 39.7
# button name:  NO2
# 4.2
# button name:  SO2
# 13.4
# city name:  Kragujevac, Central Serbia
# button name:  PM2.5
# 11.2
# button name:  NO2
# 7.7
# city name:  KOSJERIC, Central Serbia
# button name:  PM2.5
# 7.8
# button name:  PM10
# 8
# button name:  O3
# 4.6
# button name:  NO2
# 5.3
# button name:  SO2
# 4.5
# city name:  Lipe, Central Serbia
# button name:  PM2.5
# 7.5
# city name:  Belgrade, Central Serbia
# button name:  PM2.5
# 6
# button name:  PM10
# 6.2
# button name:  O3
# 63
# button name:  NO2
# 8.1
# button name:  SO2
# 16.2
# button name:  CO
# 435
# city name:  Vrsac, Autonomna Pokrajina Vojvodina
# button name:  O3
# 61.2
# button name:  NO2
# 1.6
# button name:  SO2
# 6.5
# city name:  Gornji Milanovac, Central serb
# button name:  PM2.5
# 5.2
# country:  https://www.iqair.com/slovakia
# city name:  Novaky, Nitra
# button name:  PM2.5
# 28
# button name:  PM10
# 10
# button name:  SO2
# 2
# city name:  Jelsava, Banska Bystrica
# button name:  PM2.5
# 27
# button name:  PM10
# 31
# button name:  O3
# 6
# city name:  Banska Bystrica, Banska Bystrica
# button name:  PM2.5
# 17.5
# button name:  PM10
# 14
# button name:  O3
# 3
# button name:  NO2
# 19
# city name:  Hnusta, Banska Bystrica
# button name:  PM2.5
# 22
# button name:  PM10
# 27
# city name:  Martin, Zilina
# button name:  PM2.5
# 28
# button name:  PM10
# 21
# city name:  Vranov nad Toplou, Presov
# button name:  PM2.5
# 18
# button name:  PM10
# 23
# button name:  SO2
# 7
# city name:  Moldava nad Bodvou, Kosice
# button name:  PM2.5
# 11.2
# button name:  PM10
# 12.8
# city name:  Handlova, Trencin
# button name:  PM2.5
# 21
# button name:  PM10
# 15
# city name:  Strazske, Kosice
# button name:  PM2.5
# 19
# button name:  PM10
# 20
# city name:  Zvolen-Motova, Banska Bystrica
# button name:  PM2.5
# 6
# button name:  PM10
# 8
# country:  https://www.iqair.com/spain
# city name:  Puebla de Alfinden, Aragon
# button name:  PM2.5
# 35.7
# city name:  Ourense, Galicia
# button name:  PM2.5
# 16
# button name:  PM10
# 22
# button name:  O3
# 22
# button name:  NO2
# 42
# button name:  SO2
# 2.7
# button name:  CO
# 0
# city name:  Ponferrada, Castille and Leon
# button name:  PM2.5
# 20
# button name:  PM10
# 24
# button name:  O3
# 5
# button name:  NO2
# 25
# button name:  SO2
# 6
# city name:  Pontecesures, Galicia
# button name:  PM2.5
# 24.2
# button name:  PM10
# 16.3
# button name:  O3
# 3.7
# button name:  SO2
# 1
# city name:  Sants, Catalunya
# button name:  PM2.5
# 24.5
# city name:  Palma, Balearic Islands
# button name:  PM2.5
# 5
# button name:  PM10
# 11
# button name:  O3
# 42
# button name:  NO2
# 14
# button name:  SO2
# 2.3
# button name:  CO
# 0
# city name:  Vitoria-Gasteiz, Basque Country
# button name:  PM2.5
# 23
# button name:  PM10
# 19.5
# button name:  NO2
# 32.5
# button name:  SO2
# 4
# button name:  CO
# 0
# city name:  Altsasu, Navarre
# button name:  PM2.5
# 17
# button name:  PM10
# 20
# button name:  O3
# 3
# button name:  NO2
# 34
# button name:  SO2
# 5
# city name:  Ciutat Meridiana, Catalunya
# button name:  PM2.5
# 20
# button name:  PM10
# 28
# city name:  Guadalix de la Sierra, Madrid
# button name:  PM2.5
# 17
# button name:  PM10
# 24
# button name:  NO2
# 41
# country:  https://www.iqair.com/syria
# city name:  Fiq, Quneitra
# button name:  PM2.5
# 41.9
# city name:  Arwad, Tartus
# button name:  PM2.5
# 23.4
# button name:  PM10
# 39.5
# button name:  NO2
# 7.7
# button name:  SO2
# 3.4
# finish

# %%
data = {'City': city_names, 'AQI': aqi_values, 'PM2.5': PM25, 'PM10': PM10, 'O3': O3, 'NO2': NO2, 'SO2': SO2, 'CO': CO}
df = pd.DataFrame(data)
df.to_csv("data_1.csv")
