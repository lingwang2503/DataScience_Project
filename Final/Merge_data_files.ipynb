# %%
import pandas as pd

# %%
data1 = pd.read_csv('data_1.csv', index_col = 0)
total_data = data1.copy()
data2 = pd.read_csv('data_2.csv', index_col = 0)
total_data = total_data.append(data2, ignore_index=True)
data3 = pd.read_csv('data_3.csv', index_col = 0)
total_data = total_data.append(data3, ignore_index=True)
data4 = pd.read_csv('data_4.csv', index_col = 0)
total_data = total_data.append(data4, ignore_index=True)
data5 = pd.read_csv('data_5.csv', index_col = 0)
total_data = total_data.append(data5, ignore_index=True)
data6 = pd.read_csv('data_6.csv', index_col = 0)
total_data = total_data.append(data6, ignore_index=True)
data7 = pd.read_csv('data_7.csv', index_col = 0)
total_data = total_data.append(data7, ignore_index=True)
data8 = pd.read_csv('data_8.csv', index_col = 0)
total_data = total_data.append(data8, ignore_index=True)

# %%
total_data.to_csv('total_data.csv')

# %%
total_data
# Out:
#                                 City     Level  PM2.5  PM10    O3   NO2   SO2  \
# 0                     Ube, Yamaguchi  Moderate   30.0   8.0   NaN   9.4   7.9
# 1              Hiraidemachi, Tochigi  Moderate   23.0   8.0   NaN  39.5   NaN
# 2                   Minato, Wakayama  Moderate   20.0  24.0   NaN   NaN  23.6
# 3     Mizusawaku Higashiodori, Iwate  Moderate   19.0   4.0   NaN  26.3   2.6
# 4                   Futago, Kanagawa  Moderate   15.0  11.0   NaN  73.3   NaN
# ...                              ...       ...    ...   ...   ...   ...   ...
# 1205                          Skopje      Good   10.3  12.7  34.8  15.5   1.8
# 1206                        Portland      Good    6.2   NaN   2.4   2.6   0.7
# 1207                    Vancouver BC      Good    3.2   4.2  30.0  24.7   1.0
# 1208                  Salt Lake City      Good    1.3   NaN  17.1  66.7   0.0
# 1209                       Melbourne      Good    1.9  19.9  12.3   3.6   4.1
#
#          CO
# 0       NaN
# ...
